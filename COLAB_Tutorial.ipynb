# %% [markdown]
# <a href="https://colab.research.google.com/github/jpmariscalm2014/Colab_prueba/blob/main/COLAB_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**INTRODUCTION TO COLAB**
# Source: [Google Colab Tutorial for Data Scientists](https://www.datacamp.com/tutorial/tutorial-google-colab-for-data-scientists?utm_cid=21057859163&utm_aid=157296744137&utm_campaign=230119_1-ps-other~dsa-tofu~all_2-b2c_3-latam-en_4-prc_5-na_6-na_7-le_8-pdsh-go_9-nb-e_10-na_11-na&utm_loc=9219107-&utm_mtd=-c&utm_kw=&utm_source=google&utm_medium=paid_search&utm_content=ps-other~latam-en~dsa~tofu~tutorial~data-science&gad_source=1&gad_campaignid=21057859163&gbraid=0AAAAADQ9WsGoIzMN8hj68QMWBdd8JMSje&gclid=Cj0KCQiA4eHLBhCzARIsAJ2NZoJhAuBfaReW8GNuUCePUMjsZQxkVKAJnJqtKraG9DqWhBx_pAMoKIoaAn3dEALw_wcB). DataCamp

# %% [markdown]
# **Markdown text editing commands:**
#
# 1. *Cursiva entre asterisco*
# 2. **Negrilla entre doble asterisco**
# 3. ***Negrilla y cursiva entre triple asterisco***

# %% [markdown]
# **Pre-installed *python* libraries**
# 1. Libraries for data analysis and visualization, such as NumPy, pandas, matplotlib, and seaborn
# 2. Machine learning libraries, including scikit-learn, and deep learning libraries such as PyTorch, TensorFlow and Keras

# %% [markdown]
# **Sharing and integration with GitHub**
# 1. Your notebook is located in your drive unit by-default.
# 2. You can share it trough drive for colaboration.
# 3. You can save a copy in GitHub. File/Save a copy in GitHub.

# %% [markdown]
# **Working with data from various sources**
# 1. Files loading: To upload files containing the data from your local machine, click on the 'File upload'. By default it will be saved in File path.
# 2. Files mounting from drive. After the activation of Drive you could acces to your drive throuh the path content/drive/MyDrive. Mount your drive using the drive icon or using the next script:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 3. Upload data from your drive. First an image linked by a web browser.

# %% [markdown]
# ![](https://bluuweb.github.io/tutorial-github/img/git-flujo.png)

# %% [markdown]
# Using code and a Python library for images in your Drive:

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/Colab Notebooks/Images/Captura de pantalla 2026-01-27 185540.png')

# %% [markdown]
# Using an image of your Drive:
# 1. Use this link https://drive.google.com/uc?export=view&id=XXX
# 2. Replace XXX for the File ID (https://drive.google.com/file/d/19a72N08aszR-rQtJKwfgrwgirEEHdM-h/view?usp=sharing, the part between d/ and /view)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=19a72N08aszR-rQtJKwfgrwgirEEHdM-h)

# %% [markdown]
# 4. Data frame or data from a csv

# %% [markdown]
# 5. Cloning from GitHub

# %%
# !git clone https://github.com/pytorch/pytorch
# Out:
# Cloning into 'pytorch'...
# remote: Enumerating objects: 1189971, done.
# remote: Counting objects: 100% (1503/1503), done.
# remote: Compressing objects: 100% (624/624), done.
# ^C
